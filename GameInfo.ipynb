# %%
import random
## this needs to be imported for use of random.randint()
lower_bound = int(input("please enter a lower bound."))
## lower bound is asking for lower bound as int
upper_bound = int(input("please enter an upper bound. It must be higher than lower bound."))
## upper bound is asking for upper bound as int
if lower_bound < upper_bound:
    try:  ## this entire try/except is to make sure that the game is running with the proper input of an integer. It catches that error basically

        random_num = random.randint(lower_bound, upper_bound) ##generating a random number from lower to upper bound
        ## you should set "guess" to be player input asking for the guess for that iteration of the loop
        
        ## speaking of, start a loop for gameplay! i think you need to actually specify the loop as a function to be called,
        ## try to think of what code needs to be under a certain function name, maybe "play_game()" and "get_user_guess()" could be the functions
        if guess > random_num:
            print("Your guess is high") ## then continue looping the game
        if guess < random_num:
            print("Your guess is low") ## then continue looping the game
        if guess == random_num: 
            print("Winner!") ## figure out how to stop game. "break" ?
    

        ## I think you may want this to print at the start or end of the loop to track attempts and words. Check pls.
        print("you've guessed", i, "times! Now on guess", (i+1)"!")
        ## fix this to be your variables and i think you have to define "i+1", 
        ## look at previous hw, maybe hw4?

    except ValueError:
        print("Error: Please enter a valid number!")
